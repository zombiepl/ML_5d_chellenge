# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(20,30,50)
y = x+1
plt.plot(x, y, '-b', label='satan')

plt.axhline(y=26, color='r', label='is')

x2 = np.linspace(40,30,50)
y2 = x+1
plt.plot(x2, y2, '-g', label='my')
plt.title('colorz')

x2 = np.linspace(30,30,50)
y2 = x+1
plt.plot(x2, y2, '-y', label='friend')

 # r1 = np.random.rand(4,7)
for x in range (20,30):
    {   
plt.scatter(x,x+2)
    }
plt.legend(loc='upper left')
plt.grid()
plt.show()
